# %%
import pymongo
from pymongo import MongoClient
import pprint
from IPython.display import clear_output

# Replace XXXX with your connection URI from the Atlas UI
client = MongoClient("127.0.0.1:27017")

# Like the last handout, this pipeline will not work on Atlas until MongoDB 3.6 has been released
# If you're testing this before 3.6 is released you can download and install MongoDB 3.5.X locally
# In that case you should use "mongodb://localhost:27107" as your connection URI
pipeline = [
    {
        '$limit': 100
    },
    {
        '$addFields': {
            'lastupdated': {
                '$arrayElemAt': [
                    {'$split': ["$lastupdated", "."]},
                    0
                ]}
        }
    },
    {
        '$project': {
            'title': 1,
            'year': 1,
            'directors': {'$split': ["$director", ", "]},
            'actors': {'$split': ["$cast", ", "]},
            'writers': {'$split': ["$writer", ", "]},
            'genres': {'$split': ["$genre", ", "]},
            'languages': {'$split': ["$language", ", "]},
            'countries': {'$split': ["$country", ", "]},
            'plot': 1,
            'fullPlot': "$fullplot",
            'rated': "$rating",
            'released': {
                '$cond': {
                    'if': {'$ne': ["$released", ""]},
                    'then': {
                        '$dateFromString': {
                            'dateString': "$released"
                        }
                    },
                    'else': ""}},
            'runtime': 1,
            'poster': 1,
            'imdb': {
                'id': "$imdbID",
                'rating': "$imdbRating",
                'votes': "$imdbVotes"
                },
            'metacritic': 1,
            'awards': 1,
            'type': 1,
            'lastUpdated': {
                '$cond': {
                    'if': {'$ne': ["$lastupdated", ""]},
                    'then': {
                        '$dateFromString': {
                            'dateString': "$lastupdated",
                            'timezone': "America/New_York"
                        }
                    },
                    'else': ""}}
        }
    },
    {
        '$out': "movies_scratch"
    }
]

clear_output()
pprint.pprint(list(client.mflix.movies_initial.aggregate(pipeline)))
# Out:
# [{'_id': ObjectId('5a3767934d68d8f31b2ca9f8'),
#   'awards': '',
#   'cast': 'Carmencita',
#   'country': 'USA',
#   'director': 'William K.L. Dickson',
#   'fullplot': 'Performing on what looks like a small wooden stage, wearing a '
#               'dress with a hoop skirt and white high-heeled pumps, Carmencita '
#               'does a dance with kicks and twirls, a smile always on her face.',
#   'genre': 'Documentary, Short',
#   'imdbID': 1,
#   'imdbRating': 5.9,
#   'imdbVotes': 1032,
#   'language': '',
#   'lastupdated': '2015-08-26 00:03:45.040000000',
#   'metacritic': '',
#   'plot': 'Performing on what looks like a small wooden stage, wearing a dress '
#           'with a hoop skirt and white high-heeled pumps, Carmencita does a '
#           'dance with kicks and twirls, a smile always on her face.',
#   'poster': 'http://ia.media-imdb.com/images/M/MV5BMjAzNDEwMzk3OV5BMl5BanBnXkFtZTcwOTk4OTM5Ng@@._V1_SX300.jpg',
#   'rating': 'NOT RATED',
#   'released': '',
#   'runtime': '1 min',
#   'title': 'Carmencita',
#   'type': 'movie',
#   'writer': '',
#   'year': 1894},
#  {'_id': ObjectId('5a3767934d68d8f31b2ca9f9'),
#   'awards': '',
#   'cast': '',
#   'country': 'France',
#   'director': '�mile Reynaud',
#   'fullplot': 'One night, Arlequin come to see his lover Colombine. But then '
#               'Pierrot knocks at the door and Colombine and Arlequin hide. '
#               'Pierrot starts singing but Arlequin scares him and the poor man '
#               'goes away.',
#   'genre': 'Animation, Comedy, Short',
#   'imdbID': 3,
#   'imdbRating': 6.7,
#   'imdbVotes': 566,
#   'language': '',
#   'lastupdated': '2015-08-12 00:06:02.720000000',
#   'metacritic': '',
#   'plot': 'One night, Arlequin come to see his lover Colombine. But then '
#           'Pierrot knocks at the door and Colombine and Arlequin hide. Pierrot '
#           'starts singing but Arlequin scares him and the poor man goes away.',
#   'poster': '',
#   'rating': '',
#   'released': '1892-10-28',
#   'runtime': '4 min',
#   'title': 'Pauvre Pierrot',
#   'type': 'movie',
#   'writer': '',
#   'year': 1892},
#  {'_id': ObjectId('5a3767934d68d8f31b2ca9fa'),
#   'awards': '1 win.',
#   'cast': 'Charles Kayser, John Ott',
#   'country': 'USA',
#   'director': 'William K.L. Dickson',
#   'fullplot': 'A stationary camera looks at a large anvil with a blacksmith '
#               'behind it and one on either side. The smith in the middle draws '
#               'a heated metal rod from the fire, places it on the anvil, and '
#               'all three begin a rhythmic hammering. After several blows, the '
#               'metal goes back in the fire. One smith pulls out a bottle of '
#               'beer, and they each take a swig. Then, out comes the glowing '
#               'metal and the hammering resumes.',
#   'genre': 'Short',
#   'imdbID': 5,
#   'imdbRating': 6.2,
#   'imdbVotes': 1189,
#   'language': '',
#   'lastupdated': '2015-08-26 00:03:50.133000000',
#   'metacritic': '',
#   'plot': 'Three men hammer on an anvil and pass a bottle of beer around.',
#   'poster': '',
#   'rating': 'UNRATED',
#   'released': '1893-05-09',
#   'runtime': '1 min',
#   'title': 'Blacksmith Scene',
#   'type': 'movie',
#   'writer': '',
#   'year': 1893},
#  {'_id': ObjectId('5a3767934d68d8f31b2ca9fb'),
#   'awards': '',
#   'cast': 'Fred Ott',
#   'country': 'USA',
#   'director': 'William K.L. Dickson',
#   'fullplot': "A man (Edison's assistant) takes a pinch of snuff and sneezes. "
#               'This is one of the earliest Edison films and was the first '
#               'motion picture to be copyrighted in the United States.',
#   'genre': 'Documentary, Short',
#   'imdbID': 8,
#   'imdbRating': 5.9,
#   'imdbVotes': 988,
#   'language': '',
#   'lastupdated': '2015-08-10 00:21:07.127000000',
#   'metacritic': '',
#   'plot': "A man (Thomas Edison's assistant) takes a pinch of snuff and "
#           'sneezes. This is one of the earliest Thomas Edison films and was '
#           'the first motion picture to be copyrighted in the United States.',
#   'poster': '',
#   'rating': '',
#   'released': '1894-01-09',
#   'runtime': '1 min',
#   'title': 'Edison Kinetoscopic Record of a Sneeze',
#   'type': 'movie',
#   'writer': '',
#   'year': 1894},
#  {'_id': ObjectId('5a3767934d68d8f31b2ca9fc'),
#   'awards': '',
#   'cast': '',
#   'country': 'France',
#   'director': 'Louis Lumi�re',
#   'fullplot': 'A man opens the big gates to the Lumi�re factory. Through the '
#               'gateway and a smaller doorway beside it, workers are streaming '
#               'out, turning either left or right. Most of them are women in '
#               'long dresses and big hats, but some are men. Suddenly a man '
#               'with a long apron rushes out through the crowd, followed by a '
#               'big dog. At last some men on bikes leave the gateway. When all '
#               'workers have left the factory, the doorkeeper starts closing '
#               'the gates again.',
#   'genre': 'Documentary, Short',
#   'imdbID': 10,
#   'imdbRating': 6.9,
#   'imdbVotes': 3469,
#   'language': '',
#   'lastupdated': '2015-08-26 00:03:56.603000000',
#   'metacritic': '',
#   'plot': 'A man opens the big gates to the Lumi�re factory. Through the '
#           'gateway and a smaller doorway beside it, workers are streaming out, '
#           'turning either left or right. Most of them are women in ...',
#   'poster': '',
#   'rating': '',
#   'released': '1895-03-22',
#   'runtime': '1 min',
#   'title': 'Employees Leaving the Lumi�re Factory',
#   'type': 'movie',
#   'writer': '',
#   'year': 1895},
#  {'_id': ObjectId('5a3767934d68d8f31b2ca9fd'),
#   'awards': '',
#   'cast': '',
#   'country': 'France',
#   'director': 'Auguste Lumi�re, Louis Lumi�re',
#   'fullplot': 'A group of people are standing in a straight line along the '
#               'platform of a railway station, waiting for a train, which is '
#               'seen coming at some distance. When the train stops at the '
#               'platform, the line dissolves. The doors of the railway-cars '
#               'open, and people on the platform help passengers to get off.',
#   'genre': 'Documentary, Short',
#   'imdbID': 12,
#   'imdbRating': 7.3,
#   'imdbVotes': 5043,
#   'language': '',
#   'lastupdated': '2015-08-15 00:02:53.443000000',
#   'metacritic': '',
#   'plot': 'A group of people are standing in a straight line along the '
#           'platform of a railway station, waiting for a train, which is seen '
#           'coming at some distance. When the train stops at the platform, ...',
#   'poster': 'http://ia.media-imdb.com/images/M/MV5BMjEyNDk5MDYzOV5BMl5BanBnXkFtZTgwNjIxMTEwMzE@._V1_SX300.jpg',
#   'rating': '',
#   'released': '1896-01-01',
#   'runtime': '1 min',
#   'title': 'The Arrival of a Train',
#   'type': 'movie',
#   'writer': '',
#   'year': 1896},
#  {'_id': ObjectId('5a3767934d68d8f31b2ca9fe'),
#   'awards': '',
#   'cast': 'Fran�ois Clerc, Beno�t Duval',
#   'country': 'France',
#   'director': 'Louis Lumi�re',
#   'fullplot': 'A gardener is watering his flowers, when a mischievous boy '
#               'sneaks up behind his back, and puts a foot on the water hose. '
#               'The gardener is surprised, and looks into the nozzle to find '
#               'out why the water has stopped coming. The boy lifts his foot '
#               "from the hose, whereby the water squirts up in the gardener's "
#               'face. The gardener chases the boy, grips his ear, and slaps him '
#               'in his buttocks. The boy runs away, and the gardener continues '
#               'his watering.',
#   'genre': 'Comedy, Short',
#   'imdbID': 14,
#   'imdbRating': 7.1,
#   'imdbVotes': 2554,
#   'language': '',
#   'lastupdated': '2015-08-12 00:06:18.237000000',
#   'metacritic': '',
#   'plot': 'A gardener is watering his flowers, when a mischievous boy sneaks '
#           'up behind his back, and puts a foot on the water hose. The gardener '
#           'is surprised, and looks into the nozzle to find out why...',
#   'poster': '',
#   'rating': '',
#   'released': '',
#   'runtime': '1 min',
#   'title': 'Tables Turned on the Gardener',
#   'type': 'movie',
#   'writer': '',
#   'year': 1895},
#  {'_id': ObjectId('5a3767934d68d8f31b2ca9ff'),
#   'awards': '',
#   'cast': '',
#   'country': 'France',
#   'director': 'Louis Lumi�re',
#   'fullplot': 'The sea is before us. Some rocks are visible to the right and a '
#               'narrow jetty extends about ten meters or so about three feet '
#               'above the sea, held up by two sets of pylons. A woman and '
#               'several lads about ten years old are coming out onto the rocks, '
#               'one climbs onto the jetty at the end. He jumps back into the '
#               'sea as the lads and lady run out to the end of the jetty and '
#               'jump off. Even though the sea looks to be only about a foot '
#               'deep, one boy does a flip into the water and repeats it later. '
#               'The others simply jump in.',
#   'genre': 'Documentary, Short',
#   'imdbID': 23,
#   'imdbRating': 5.5,
#   'imdbVotes': 599,
#   'language': '',
#   'lastupdated': '2015-08-12 00:06:30.297000000',
#   'metacritic': '',
#   'plot': 'Several little boys run along a pier, then jump into the ocean.',
#   'poster': '',
#   'rating': '',
#   'released': '1896-06-28',
#   'runtime': '1 min',
#   'title': 'The Sea',
#   'type': 'movie',
#   'writer': '',
#   'year': 1895},
#  {'_id': ObjectId('5a3767934d68d8f31b2caa00'),
#   'awards': '',
#   'cast': 'Auguste Lumi�re',
#   'country': 'France',
#   'director': 'Louis Lumi�re',
#   'fullplot': 'Auguste Lumi�re directs four workers in the demolition of an '
#               'old wall at the Lumi�re factory. One worker is pressing the '
#               'wall inwards with a jackscrew, while another is pushing it with '
#               'a pick. When the wall hits the ground, a cloud of white dust '
#               'whirls up. Three workers continue the demolition of the wall '
#               'with picks.',
#   'genre': 'Documentary, Short',
#   'imdbID': 70,
#   'imdbRating': 6.4,
#   'imdbVotes': 1359,
#   'language': '',
#   'lastupdated': '2015-08-26 00:05:47.977000000',
#   'metacritic': '',
#   'plot': 'Auguste Lumi�re directs four workers in the demolition of an old '
#           'wall at the Lumi�re factory. One worker is pressing the wall '
#           'inwards with a jackscrew, while another is pushing it with a ...',
#   'poster': '',
#   'rating': '',
#   'released': '2005-04-15',
#   'runtime': '1 min',
#   'title': "D�molition d'un mur",
#   'type': 'movie',
#   'writer': '',
#   'year': 1896},
#  {'_id': ObjectId('5a3767934d68d8f31b2caa01'),
#   'awards': '',
#   'cast': 'Mrs. Auguste Lumiere, Andr�e Lumi�re, Auguste Lumi�re',
#   'country': 'France',
#   'director': 'Louis Lumi�re',
#   'fullplot': 'A baby is seated at a table between its cheerful parents, '
#               'Auguste and Marguerite Lumi�re. While the father is feeding the '
#               'baby with a spoon, the mother is pouring coffee into her cup. '
#               'The father gives the baby a biscuit, which the baby grabs, but '
#               "doesn't eat, although both parents encourage it. The father "
#               'resumes feeding the baby with the spoon.',
#   'genre': 'Documentary, Short',
#   'imdbID': 29,
#   'imdbRating': 5.9,
#   'imdbVotes': 1669,
#   'language': '',
#   'lastupdated': '2015-08-12 00:06:40.657000000',
#   'metacritic': '',
#   'plot': 'A baby is seated at a table between its cheerful parents, Auguste '
#           'and Marguerite Lumi�re. While the father is feeding the baby with a '
#           'spoon, the mother is pouring coffee into her cup. The ...',
#   'poster': '',
#   'rating': '',
#   'released': '1895-12-28',
#   'runtime': '1 min',
#   'title': "Baby's Dinner",
#   'type': 'movie',
#   'writer': '',
#   'year': 1895},
#  {'_id': ObjectId('5a3767934d68d8f31b2caa02'),
#   'awards': '',
#   'cast': "Jeanne d'Alcy, Georges M�li�s",
#   'country': 'France',
#   'director': 'Georges M�li�s',
#   'fullplot': 'A bat flies into an ancient castle and transforms itself into '
#               'Mephistopheles himself. Producing a cauldron, Mephistopheles '
#               'conjures up a young girl and various supernatural creatures, '
#               'one of which brandishes a crucifix in an effort to force the '
#               'devil-vampire to vanish.',
#   'genre': 'Short, Horror',
#   'imdbID': 91,
#   'imdbRating': 6.8,
#   'imdbVotes': 1135,
#   'language': '',
#   'lastupdated': '2015-08-26 00:06:16.697000000',
#   'metacritic': '',
#   'plot': 'A bat flies into an ancient castle and transforms itself into '
#           'Mephistopheles himself. Producing a cauldron, Mephistopheles '
#           'conjures up a young girl and various supernatural creatures, one '
#           '...',
#   'poster': '',
#   'rating': '',
#   'released': '',
#   'runtime': '3 min',
#   'title': 'The House of the Devil',
#   'type': 'movie',
#   'writer': 'Georges M�li�s',
#   'year': 1896},
#  {'_id': ObjectId('5a3767934d68d8f31b2caa03'),
#   'awards': '',
#   'cast': 'Georges M�li�s',
#   'country': 'France',
#   'director': 'Georges M�li�s',
#   'fullplot': "A man tries to get a good night's sleep, but is disturbed by a "
#               'giant spider that leaps onto his bed, and a battle ensues in '
#               'hilarious comic fashion.',
#   'genre': 'Short, Comedy',
#   'imdbID': 131,
#   'imdbRating': 5.9,
#   'imdbVotes': 498,
#   'language': '',
#   'lastupdated': '2015-08-26 00:07:48.213000000',
#   'metacritic': '',
#   'plot': "A man tries to get a good night's sleep, but is disturbed by a "
#           'giant spider that leaps onto his bed, and a battle ensues in '
#           'hilarious comic fashion.',
#   'poster': '',
#   'rating': '',
#   'released': '',
#   'runtime': '1 min',
#   'title': 'A Terrible Night',
#   'type': 'movie',
#   'writer': '',
#   'year': 1896},
#  {'_id': ObjectId('5a3767934d68d8f31b2caa04'),
#   'awards': '',
#   'cast': "Jeanne d'Alcy, Georges M�li�s",
#   'country': 'France',
#   'director': 'Georges M�li�s',
#   'fullplot': 'An elegantly dressed man enters through a stage door onto a set '
#               'with decorated back screen, a chair and small table. He brings '
#               'a well-dressed women through the door, spreads a newspaper on '
#               'the floor, and places the chair on it. She sits and fans '
#               'herself; he covers her with a diaphanous cloth. She disappears; '
#               'he tries to conjure her back with incomplete results. Can he go '
#               'beyond the bare bones of a conjuring trick and succeed in the '
#               'complete reconstitution of a the lady?',
#   'genre': 'Short',
#   'imdbID': 75,
#   'imdbRating': 6.3,
#   'imdbVotes': 759,
#   'language': '',
#   'lastupdated': '2015-08-26 00:05:55.493000000',
#   'metacritic': '',
#   'plot': 'A woman disappears on stage.',
#   'poster': '',
#   'rating': '',
#   'released': '',
#   'runtime': '1 min',
#   'title': 'The Conjuring of a Woman at the House of Robert Houdin',
#   'type': 'movie',
#   'writer': '',
#   'year': 1896},
#  {'_id': ObjectId('5a3767934d68d8f31b2caa05'),
#   'awards': '',
#   'cast': 'Georges M�li�s',
#   'country': 'France',
#   'director': 'Georges M�li�s',
#   'fullplot': 'A weary traveler stops at an inn along the way to get a good '
#               "night's sleep, but his rest is interrupted by odd happenings "
#               'when he gets to his room--beds vanishing and re-appearing, '
#               'candles exploding, pants flying through the air and his shoes '
#               'walking away by themselves.',
#   'genre': 'Short, Comedy',
#   'imdbID': 138,
#   'imdbRating': 6.5,
#   'imdbVotes': 329,
#   'language': '',
#   'lastupdated': '2015-08-29 00:17:59.703000000',
#   'metacritic': '',
#   'plot': 'A weary traveler stops at an inn along the way to get a good '
#           "night's sleep, but his rest is interrupted by odd happenings when "
#           'he gets to his room--beds vanishing and re-appearing, candles ...',
#   'poster': '',
#   'rating': '',
#   'released': '',
#   'runtime': '2 min',
#   'title': 'The Bewitched Inn',
#   'type': 'movie',
#   'writer': 'Georges M�li�s',
#   'year': 1897},
#  {'_id': ObjectId('5a3767934d68d8f31b2caa06'),
#   'awards': '',
#   'cast': 'Gaston M�li�s, Georges M�li�s, Georgette M�li�s',
#   'country': 'France',
#   'director': 'Georges M�li�s',
#   'fullplot': 'Three friends are playing cards in a beer garden. One of them '
#               'orders drinks. The waitress comes back with a bottle of wine '
#               'and three glasses on a tray. The man serves his friends. They '
#               'clink glasses and drink. Then the man asks for a newspaper. He '
#               'reads a funny story in it and the three friends burst out '
#               'laughing while the waitress merely smiles.',
#   'genre': 'Short, Biography',
#   'imdbID': 132,
#   'imdbRating': 5.1,
#   'imdbVotes': 462,
#   'language': '',
#   'lastupdated': '2015-07-27 00:27:37.370000000',
#   'metacritic': '',
#   'plot': 'Three friends are playing cards in a beer garden. One of them '
#           'orders drinks. The waitress comes back with a bottle of wine and '
#           'three glasses on a tray. The man serves his friends. They ...',
#   'poster': '',
#   'rating': '',
#   'released': '',
#   'runtime': '1 min',
#   'title': 'Une partie de cartes',
#   'type': 'movie',
#   'writer': 'Georges M�li�s',
#   'year': 1896},
#  {'_id': ObjectId('5a3767934d68d8f31b2caa07'),
#   'awards': '',
#   'cast': 'Ella Lola',
#   'country': 'USA',
#   'director': 'James H. White',
#   'fullplot': 'Dancer Ella Lola dances a routine based on the famous character '
#               'of "Trilby".',
#   'genre': 'Short',
#   'imdbID': 192,
#   'imdbRating': 4.7,
#   'imdbVotes': 83,
#   'language': '',
#   'lastupdated': '2015-08-29 00:19:44.140000000',
#   'metacritic': '',
#   'plot': 'Dancer Ella Lola dances a routine based on the famous character of '
#           '"Trilby".',
#   'poster': '',
#   'rating': '',
#   'released': '',
#   'runtime': '',
#   'title': 'Ella Lola, a la Trilby',
#   'type': 'movie',
#   'writer': 'George L. Du Maurier (novel)',
#   'year': 1898},
#  {'_id': ObjectId('5a3767934d68d8f31b2caa08'),
#   'awards': '',
#   'cast': 'Georges M�li�s',
#   'country': 'France',
#   'director': 'Georges M�li�s',
#   'fullplot': '"In the opening of this film is seen the astronomer intently '
#               'poring over his books. Suddenly, in a cloud of smoke, Satan '
#               'appears and surprises the astronomer. At the command of the '
#               'Fairy Queen, who suddenly appears, Satan vanishes; she awakens '
#               'the astronomer and as he goes forward to meet her she '
#               'disappears. The astronomer is very much excited, and, rushing '
#               'over to the large telescope he tries to discover by what means '
#               'she had vanished. The moon now appears, and begins her repast '
#               'by eating the immense telescope used by the astronomer. The '
#               'astronomer flies around apparently wild at the loss of his '
#               'wonderful telescope. Suddenly the moon opens wide her mouth and '
#               'there comes forth a tot of about five summers. She is '
#               'immediately followed by two others, and they proceed to dance '
#               'around the astronomer, and vanish one at a time until but one '
#               'is left. The astronomer, picking her up, thinking he could keep '
#               'her, hugs her tightly in his arms, but she also vanishes. Tired '
#               'and heart-broken the astronomer grasps a broom and attempts to '
#               'strike the moon, when she suddenly vanishes and in the distance '
#               'laughs at him, rolling his eyes forward and backward, '
#               'apparently convulsed with laughter. The moon suddenly changes '
#               'to a crescent, and a fairy appears sitting on it. The veiled '
#               'figure which stands before him throws back its veil and becomes '
#               'animated; he rushes forward and grasps it, when, to his utter '
#               'amazement, it disappears in the air. The Fairy Queen appears in '
#               'the crescent. She first seats herself, and the astronomer puts '
#               'his arms out for her, thinking perhaps he can reach her, when '
#               'she disappears and in her place there stands a marble statue of '
#               'a man. The astronomer, in his efforts to reach her falls to the '
#               'ground. Rising and seeing the statue he is so incensed that he '
#               'grabs a club, and as he is about to crush the statue it '
#               'suddenly becomes alive. The large moon again appearing to his '
#               'view he throws himself into it, and the moon, winking one eye, '
#               "proceeds to chew him up. The moon's large teeth are seen to "
#               'sink into the astronomer again and again until he is reduced to '
#               "small pieces, when piece by piece he is ejected from the moon's "
#               'mouth and lies there, one piled on the other. Suddenly in a '
#               'cloud of smoke, Satan appears, but the Fairy Queen drives him '
#               'off again. She proceeds to pick up different parts of the '
#               'astronomer and hurls them across the room, and piece by piece '
#               'they take their proper position in the chair, until the '
#               'astronomer is again seated as he was before. Suddenly he comes '
#               'to life again. He moves forward to grasp the Fairy Queen, when '
#               'suddenly she disappears. The scene is again laid in the '
#               "astronomer's observatory, the astronomer sitting at the table, "
#               'asleep over his volume, which he has been studying."',
#   'genre': 'Short, Fantasy',
#   'imdbID': 211,
#   'imdbRating': 7.6,
#   'imdbVotes': 1057,
#   'language': '',
#   'lastupdated': '2015-08-29 00:20:20.280000000',
#   'metacritic': '',
#   'plot': '"In the opening of this film is seen the astronomer intently poring '
#           'over his books. Suddenly, in a cloud of smoke, Satan appears and '
#           'surprises the astronomer. At the command of the Fairy ...',
#   'poster': '',
#   'rating': '',
#   'released': '',
#   'runtime': '3 min',
#   'title': 'A Trip to the Moon',
#   'type': 'movie',
#   'writer': 'Georges M�li�s (creator)',
#   'year': 1898},
#  {'_id': ObjectId('5a3767934d68d8f31b2caa09'),
#   'awards': '',
#   'cast': 'Georges M�li�s',
#   'country': 'France',
#   'director': 'Georges M�li�s',
#   'fullplot': '',
#   'genre': 'Short, Fantasy',
#   'imdbID': 242,
#   'imdbRating': 6.3,
#   'imdbVotes': 388,
#   'language': '',
#   'lastupdated': '2015-08-29 00:21:15.827000000',
#   'metacritic': '',
#   'plot': '',
#   'poster': 'http://ia.media-imdb.com/images/M/MV5BMjM1NTQyNDQxOV5BMl5BanBnXkFtZTgwMTQ1MzUwMzE@._V1_SX300.jpg',
#   'rating': '',
#   'released': '1900-06-30',
#   'runtime': '3 min',
#   'title': 'The Sign of the Cross',
#   'type': 'movie',
#   'writer': 'Georges M�li�s',
#   'year': 1899},
#  {'_id': ObjectId('5a3767934d68d8f31b2caa0a'),
#   'awards': '',
#   'cast': 'Georges M�li�s',
#   'country': 'France',
#   'director': 'Georges M�li�s',
#   'fullplot': '',
#   'genre': 'Short',
#   'imdbID': 246,
#   'imdbRating': 6.6,
#   'imdbVotes': 580,
#   'language': '',
#   'lastupdated': '2015-08-29 00:21:21.547000000',
#   'metacritic': '',
#   'plot': '',
#   'poster': '',
#   'rating': '',
#   'released': '',
#   'runtime': '1 min',
#   'title': 'A Turn of the Century Illusionist',
#   'type': 'movie',
#   'writer': '',
#   'year': 1899},
#  {'_id': ObjectId('5a3767934d68d8f31b2caa0b'),
#   'awards': '',
#   'cast': "Barral, Bleuette Bernon, Carmely, Jeanne d'Alcy",
#   'country': 'France',
#   'director': 'Georges M�li�s',
#   'fullplot': "A fairy godmother magically turns Cinderella's rags to a "
#               'beautiful dress, and a pumpkin into a coach. Cinderella goes to '
#               'the ball, where she meets the Prince - but will she remember to '
#               'leave before the magic runs out?',
#   'genre': 'Drama, Short',
#   'imdbID': 230,
#   'imdbRating': 6.6,
#   'imdbVotes': 586,
#   'language': '',
#   'lastupdated': '2015-08-29 00:20:56.217000000',
#   'metacritic': '',
#   'plot': "A fairy godmother magically turns Cinderella's rags to a beautiful "
#           'dress, and a pumpkin into a coach. Cinderella goes to the ball, '
#           'where she meets the Prince - but will she remember to leave before '
#           'the magic runs out?',
#   'poster': 'http://ia.media-imdb.com/images/M/MV5BMTgwMDY1MzM1NV5BMl5BanBnXkFtZTgwMjM1MzUwMzE@._V1_SX300.jpg',
#   'rating': '',
#   'released': '1899-12-25',
#   'runtime': '6 min',
#   'title': 'Cinderella',
#   'type': 'movie',
#   'writer': 'Charles Perrault (story)',
#   'year': 1899},
#  {'_id': ObjectId('5a3767934d68d8f31b2caa0c'),
#   'awards': '',
#   'cast': 'Laura Bayley, Tom Green',
#   'country': 'UK',
#   'director': 'George Albert Smith',
#   'fullplot': 'A man and woman festively dressed in costumes are dreaming. '
#               "They wake to drink, play, and smoke. He snuggles her; she's "
#               "happily willing. Suddenly, the scene ends and he's but a homely "
#               'man in a loveless bed with a homely woman - husband and wife.',
#   'genre': 'Short, Comedy',
#   'imdbID': 313,
#   'imdbRating': 5.9,
#   'imdbVotes': 378,
#   'language': '',
#   'lastupdated': '2015-08-29 00:23:19.547000000',
#   'metacritic': '',
#   'plot': 'A man dreams he is flirting with an attractive young lady, then he '
#           'wakes up in bed next to his wife.',
#   'poster': '',
#   'rating': '',
#   'released': '1900-08-01',
#   'runtime': '1 min',
#   'title': 'Let Me Dream Again',
#   'type': 'movie',
#   'writer': '',
#   'year': 1900},
#  {'_id': ObjectId('5a3767934d68d8f31b2caa0d'),
#   'awards': '',
#   'cast': 'Harold Smith',
#   'country': 'UK',
#   'director': 'George Albert Smith',
#   'fullplot': "A child borrows his grandmother's magnifying glass to look at a "
#               'newspaper ad for Bovril, at a watch, and then at a bird. The '
#               'child shows grandma what he is doing. The child looks next at '
#               "grandma's eye, then at a kitten.",
#   'genre': 'Short',
#   'imdbID': 304,
#   'imdbRating': 6.1,
#   'imdbVotes': 555,
#   'language': '',
#   'lastupdated': '2015-08-29 00:23:05.170000000',
#   'metacritic': '',
#   'plot': 'A boy looks through glasses at various objects, seen magnified.',
#   'poster': '',
#   'rating': '',
#   'released': '1900-11-01',
#   'runtime': '2 min',
#   'title': "Grandma's Reading Glass",
#   'type': 'movie',
#   'writer': '',
#   'year': 1900},
#  {'_id': ObjectId('5a3767934d68d8f31b2caa0e'),
#   'awards': '',
#   'cast': 'Georges M�li�s',
#   'country': 'France',
#   'director': 'Georges M�li�s',
#   'fullplot': 'A chemist in his laboratory places upon a table his own head, '
#               'alive; then fixing upon his head a rubber tube with a pair of '
#               'bellows, he begins to blow with all his might. Immediately the '
#               'head increases in size and continues to enlarge until it '
#               'becomes truly colossal while making faces. The chemist, fearing '
#               'to burst it, opens a cock in the tube. The head immediately '
#               'contracts and resumes its original size. He then calls his '
#               'assistant and informs him of his discovery. The assistant, '
#               'wishing to experiment for himself, seizes the bellows and blows '
#               'into the head with all his might. The head swells until it '
#               'bursts with a crash, knocking over the two experimenters.',
#   'genre': 'Short, Comedy',
#   'imdbID': 359,
#   'imdbRating': 7.2,
#   'imdbVotes': 1439,
#   'language': '',
#   'lastupdated': '2015-08-29 00:24:23.860000000',
#   'metacritic': '',
#   'plot': 'A chemist in his laboratory places upon a table his own head, '
#           'alive; then fixing upon his head a rubber tube with a pair of '
#           'bellows, he begins to blow with all his might. Immediately the ...',
#   'poster': '',
#   'rating': '',
#   'released': '',
#   'runtime': '3 min',
#   'title': 'The India Rubber Head',
#   'type': 'movie',
#   'writer': '',
#   'year': 1901},
#  {'_id': ObjectId('5a3767934d68d8f31b2caa0f'),
#   'awards': '',
#   'cast': '',
#   'country': 'USA',
#   'director': 'Edwin S. Porter',
#   'fullplot': 'Panoramic view of the 1901 Pan-American Exposition filmed at '
#               'night. According to Edwin S. Porter, this is the first American '
#               'film ever shot at night using incandescent light.',
#   'genre': 'Documentary, Short',
#   'imdbID': 364,
#   'imdbRating': 5.6,
#   'imdbVotes': 87,
#   'language': 'English',
#   'lastupdated': '2015-08-29 00:24:31.077000000',
#   'metacritic': '',
#   'plot': 'A most perfect picture of the Pan-American Exposition buildings, '
#           'including the Electric Tower and Temple of Music, as they appear at '
#           'night.',
#   'poster': '',
#   'rating': '',
#   'released': '1901-11-01',
#   'runtime': '1 min',
#   'title': 'Panorama of Esplanade by Night',
#   'type': 'movie',
#   'writer': '',
#   'year': 1901},
#  {'_id': ObjectId('5a3767934d68d8f31b2caa10'),
#   'awards': '',
#   'cast': 'Thomas White',
#   'country': 'USA',
#   'director': 'George S. Fleming, Edwin S. Porter',
#   'fullplot': "Porter's sequential continuity editing links several shots to "
#               'form a narrative of the famous fairy tale story of Jack and his '
#               'magic beanstalk. Borrowing on cinematographic methods '
#               "reminiscent of 'Georges Melies', Porter uses animation, double "
#               "exposure, and trick photography to illustrate the fairy's "
#               "apparitions, Jack's dream, and the fast growing beanstalk.",
#   'genre': 'Short, Fantasy',
#   'imdbID': 399,
#   'imdbRating': 6.2,
#   'imdbVotes': 442,
#   'language': 'English',
#   'lastupdated': '2015-08-29 00:25:25.360000000',
#   'metacritic': '',
#   'plot': "Porter's sequential continuity editing links several shots to form "
#           'a narrative of the famous fairy tale story of Jack and his magic '
#           'beanstalk. Borrowing on cinematographic methods ...',
#   'poster': 'http://ia.media-imdb.com/images/M/MV5BMjAzNTI3MzI0Nl5BMl5BanBnXkFtZTcwMzQ1MTYzMw@@._V1_SX300.jpg',
#   'rating': '',
#   'released': '1902-07-15',
#   'runtime': '10 min',
#   'title': 'Jack and the Beanstalk',
#   'type': 'movie',
#   'writer': '',
#   'year': 1902},
#  {'_id': ObjectId('5a3767934d68d8f31b2caa11'),
#   'awards': '',
#   'cast': 'Fran�ois Lallement, Jules-Eug�ne Legris',
#   'country': 'France',
#   'director': 'Georges M�li�s',
#   'fullplot': 'A group of men travel to the moon by being shot in a capsule '
#               'from a giant cannon. They are captured by moon-men, escape, and '
#               'return to the earth.',
#   'genre': 'Short, Adventure, Fantasy',
#   'imdbID': 417,
#   'imdbRating': 8.2,
#   'imdbVotes': 23904,
#   'language': '',
#   'lastupdated': '2015-09-01 00:16:55.443000000',
#   'metacritic': '',
#   'plot': 'A group of astronomers go on an expedition to the moon.',
#   'poster': 'http://ia.media-imdb.com/images/M/MV5BMTQzMDYxNzUxNl5BMl5BanBnXkFtZTgwMjgxNjkxMTE@._V1_SX300.jpg',
#   'rating': 'TV-G',
#   'released': '1902-10-04',
#   'runtime': '13 min',
#   'title': 'A Trip to the Moon',
#   'type': 'movie',
#   'writer': '',
#   'year': 1902},
#  {'_id': ObjectId('5a3767934d68d8f31b2caa12'),
#   'awards': '',
#   'cast': 'Vivian Vaughan, Arthur White, James H. White',
#   'country': 'USA',
#   'director': 'George S. Fleming, Edwin S. Porter',
#   'fullplot': "Porter's sequential continuity editing links several shots to "
#               'form a narrative of firemen responding to a house fire. They '
#               'leave the station with their horse drawn pumper, arrive on the '
#               'scene, and effect the safe rescue of a woman from the burning '
#               'house. But wait, she tells them of her child yet asleep in the '
#               'burning bedroom . . .',
#   'genre': 'Short, Action',
#   'imdbID': 447,
#   'imdbRating': 6.4,
#   'imdbVotes': 1158,
#   'language': 'English',
#   'lastupdated': '2015-08-29 00:26:36.093000000',
#   'metacritic': '',
#   'plot': "Porter's sequential continuity editing links several shots to form "
#           'a narrative of firemen responding to a house fire. They leave the '
#           'station with their horse drawn pumper, arrive on the ...',
#   'poster': 'http://ia.media-imdb.com/images/M/MV5BMjAzNTI3MzI0Nl5BMl5BanBnXkFtZTcwMzQ1MTYzMw@@._V1_SX300.jpg',
#   'rating': 'NOT RATED',
#   'released': '1903-01-01',
#   'runtime': '6 min',
#   'title': 'Life of an American Fireman',
#   'type': 'movie',
#   'writer': '',
#   'year': 1903},
#  {'_id': ObjectId('5a3767934d68d8f31b2caa13'),
#   'awards': '',
#   'cast': 'May Clark, Cecil M. Hepworth, Blair, Geoffrey Faithfull',
#   'country': 'UK',
#   'director': 'Cecil M. Hepworth, Percy Stow',
#   'fullplot': 'Alice dozes in a garden, awakened by a dithering white rabbit '
#               'in waistcoat with pocket watch. She follows him down a hole and '
#               'finds herself in a hall of many doors. A key opens a small '
#               "door: eventually, she's through into a garden where a dog "
#               "awaits. Later, in the rabbit's home, her size is again a "
#               'problem. She tries to help a nanny with a howling baby, then a '
#               'Cheshire cat directs her to a tea party where the Mad Hatter '
#               'and March Hare dunk a dormouse. Expelled from the party, Alice '
#               'happens on a royal processional: all the cards in the deck '
#               'precede the Queen of Hearts, who welcomes then turns on Alice '
#               'and calls on the royal executioner. Alice must run for her '
#               'life.',
#   'genre': 'Fantasy, Short',
#   'imdbID': 420,
#   'imdbRating': 6.3,
#   'imdbVotes': 1572,
#   'language': '',
#   'lastupdated': '2015-08-22 00:28:40.907000000',
#   'metacritic': '',
#   'plot': 'Alice dozes in a garden, awakened by a dithering white rabbit in '
#           'waistcoat with pocket watch. She follows him down a hole and finds '
#           'herself in a hall of many doors. A key opens a small door...',
#   'poster': '',
#   'rating': '',
#   'released': '1903-10-17',
#   'runtime': '8 min',
#   'title': 'Alice in Wonderland',
#   'type': 'movie',
#   'writer': 'Lewis Carroll (novel), Cecil M. Hepworth',
#   'year': 1903},
#  {'_id': ObjectId('5a3767934d68d8f31b2caa14'),
#   'awards': '',
#   'cast': 'Georges M�li�s',
#   'country': 'France',
#   'director': 'Georges M�li�s',
#   'fullplot': 'A marching band appears, and the band-leader prepares to give '
#               'them the music for the song he wants them to play. He has '
#               'prepared a large staff above their heads, and he now creates '
#               'notes by making duplicates of his own head, placing them on the '
#               'staff, and completing the notes with sticks and other '
#               'implements taken from the band members. When he has finished, '
#               'the players attempt to perform the music that has been written '
#               'in such an unusual fashion.',
#   'genre': 'Short, Comedy, Music',
#   'imdbID': 455,
#   'imdbRating': 6.9,
#   'imdbVotes': 1121,
#   'language': 'French',
#   'lastupdated': '2015-08-29 00:26:51.467000000',
#   'metacritic': '',
#   'plot': 'The leader of a marching band demonstrates an unusual way of '
#           'writing music.',
#   'poster': '',
#   'rating': '',
#   'released': '1903-08-15',
#   'runtime': '3 min',
#   'title': 'The Music Lover',
#   'type': 'movie',
#   'writer': '',
#   'year': 1903},
#  {'_id': ObjectId('5a3767934d68d8f31b2caa15'),
#   'awards': '1 win.',
#   'cast': "A.C. Abadie, Gilbert M. 'Broncho Billy' Anderson, George Barnes, "
#           'Justus D. Barnes',
#   'country': 'USA',
#   'director': 'Edwin S. Porter',
#   'fullplot': 'Among the earliest existing films in American cinema - notable '
#               'as the first film that presented a narrative story to tell - it '
#               'depicts a group of cowboy outlaws who hold up a train and rob '
#               "the passengers. They are then pursued by a Sheriff's posse. "
#               'Several scenes have color included - all hand tinted.',
#   'genre': 'Short, Western',
#   'imdbID': 439,
#   'imdbRating': 7.4,
#   'imdbVotes': 9847,
#   'language': 'English',
#   'lastupdated': '2015-08-13 00:27:59.177000000',
#   'metacritic': '',
#   'plot': 'A group of bandits stage a brazen train hold-up, only to find a '
#           'determined posse hot on their heels.',
#   'poster': 'http://ia.media-imdb.com/images/M/MV5BMTQ4NDE5MDcyNF5BMl5BanBnXkFtZTgwNDU3Njk5MTE@._V1_SX300.jpg',
#   'rating': 'TV-G',
#   'released': '1903-12-01',
#   'runtime': '11 min',
#   'title': 'The Great Train Robbery',
#   'type': 'movie',
#   'writer': '',
#   'year': 1903},
#  {'_id': ObjectId('5a3767934d68d8f31b2caa16'),
#   'awards': '',
#   'cast': '',
#   'country': 'UK',
#   'director': 'George Albert Smith',
#   'fullplot': 'A simple scene of two rather flamboyantly-dressed Edwardian '
#               'children attempting to feed a spoonful of medicine to a sick '
#               'kitten. The film is important for being one of the earliest '
#               'films to cut to a close-up, then back again to the same medium '
#               'shot as before',
#   'genre': 'Short, Comedy, Family',
#   'imdbID': 469,
#   'imdbRating': 5.9,
#   'imdbVotes': 468,
#   'language': '',
#   'lastupdated': '2015-08-16 00:16:38.370000000',
#   'metacritic': '',
#   'plot': 'A girl gives a spoonful of medicine to a kitten.',
#   'poster': '',
#   'rating': '',
#   'released': '',
#   'runtime': '1 min',
#   'title': 'The Sick Kitten',
#   'type': 'movie',
#   'writer': '',
#   'year': 1903},
#  {'_id': ObjectId('5a3767934d68d8f31b2caa17'),
#   'awards': '',
#   'cast': '',
#   'country': 'France',
#   'director': 'Alice Guy',
#   'fullplot': '',
#   'genre': 'Short',
#   'imdbID': 437,
#   'imdbRating': 5.3,
#   'imdbVotes': 86,
#   'language': '',
#   'lastupdated': '2015-08-29 00:26:22.187000000',
#   'metacritic': '',
#   'plot': '',
#   'poster': '',
#   'rating': '',
#   'released': '',
#   'runtime': '2 min',
#   'title': 'Faust et M�phistoph�l�s',
#   'type': 'movie',
#   'writer': '',
#   'year': 1903},
#  {'_id': ObjectId('5a3767934d68d8f31b2caa18'),
#   'awards': '',
#   'cast': 'Bleuette Bernon, Georges M�li�s',
#   'country': 'France',
#   'director': 'Georges M�li�s',
#   'fullplot': 'At the royal court, a prince is presenting the princess whom he '
#               'is pledged to marry, when a witch suddenly appears. Though '
#               'driven off, the witch soon returns, summons some of her '
#               'servants, and carries off the princess. A rescue party is '
#               'quickly organized, but the unfortunate captive has been taken '
#               'to a strange, forbidding realm, from where it will be '
#               'impossible to rescue her without some special help.',
#   'genre': 'Short, Adventure, Fantasy',
#   'imdbID': 465,
#   'imdbRating': 7.3,
#   'imdbVotes': 574,
#   'language': '',
#   'lastupdated': '2015-08-29 00:27:10.813000000',
#   'metacritic': '',
#   'plot': 'At the royal court, a prince is presenting the princess whom he is '
#           'pledged to marry, when a witch suddenly appears. Though driven off, '
#           'the witch soon returns, summons some of her servants, ...',
#   'poster': 'http://ia.media-imdb.com/images/M/MV5BMjM3MTIwOTU0NV5BMl5BanBnXkFtZTgwNDM1MzUwMzE@._V1_SX300.jpg',
#   'rating': '',
#   'released': '1903-09-05',
#   'runtime': '16 min',
#   'title': 'Fairyland: A Kingdom of Fairies',
#   'type': 'movie',
#   'writer': "Georges M�li�s, Marie-Catherine le Jumel d'Aulnoy (story)",
#   'year': 1903},
#  {'_id': ObjectId('5a3767934d68d8f31b2caa19'),
#   'awards': '',
#   'cast': 'Blair, May Clark, Barbara Hepworth, Cecil M. Hepworth',
#   'country': 'UK',
#   'director': 'Lewin Fitzhamon, Cecil M. Hepworth',
#   'fullplot': 'Rescued by Rover is a film about a dog. Not only is it a film '
#               'about a dog it is also a film about the kidnaping of a young '
#               'baby by an old woman. With these two classical Hollywood '
#               "ingredients and some stunning dialogue, (It's silent!), Rescued "
#               'by Rover really hits a nerve. The repeated shots provide some '
#               'interest in what, surprisingly, is an entertaining example of '
#               'early cinema, canine heroics and a man wearing mascara.',
#   'genre': 'Short, Drama, Family',
#   'imdbID': 498,
#   'imdbRating': 6.7,
#   'imdbVotes': 666,
#   'language': '',
#   'lastupdated': '2015-08-29 00:28:01.313000000',
#   'metacritic': '',
#   'plot': 'A dog leads its master to his kidnapped baby.',
#   'poster': '',
#   'rating': '',
#   'released': '1905-08-19',
#   'runtime': '7 min',
#   'title': 'Rescued by Rover',
#   'type': 'movie',
#   'writer': 'Mrs. Hepworth (story)',
#   'year': 1905},
#  {'_id': ObjectId('5a3767934d68d8f31b2caa1a'),
#   'awards': '1 win.',
#   'cast': 'Martin Fuller, Mrs. William Bechtel, Walter Edwin, Ethel Jewett',
#   'country': 'USA',
#   'director': 'Harold M. Shaw',
#   'fullplot': 'Thanks to the Fresh Air Fund, a slum child escapes his drunken '
#               "mother for a day's outing in the country. Upon arriving, he and "
#               'the other children are told a story about a mythical land of no '
#               "pain. Rather then return to the slum at day's end, the lad "
#               'seeks to journey to that beautiful land beyond the sunset.',
#   'genre': 'Short, Drama, Fantasy',
#   'imdbID': 488,
#   'imdbRating': 7.1,
#   'imdbVotes': 448,
#   'language': 'English',
#   'lastupdated': '2015-08-29 00:27:45.437000000',
#   'metacritic': '',
#   'plot': 'A young boy, opressed by his mother, goes on an outing in the '
#           'country with a social welfare group where he dares to dream of a '
#           'land where the cares of his ordinary life fade.',
#   'poster': 'http://ia.media-imdb.com/images/M/MV5BMTMzMDcxMjgyNl5BMl5BanBnXkFtZTcwOTgxNjg4Mg@@._V1_SX300.jpg',
#   'rating': 'UNRATED',
#   'released': '1912-10-28',
#   'runtime': '14 min',
#   'title': 'The Land Beyond the Sunset',
#   'type': 'movie',
#   'writer': 'Dorothy G. Shore',
#   'year': 1912},
#  {'_id': ObjectId('5a3767934d68d8f31b2caa1b'),
#   'awards': '',
#   'cast': 'Georges M�li�s',
#   'country': 'France',
#   'director': 'Georges M�li�s',
#   'fullplot': 'Using every known means of transportation, several savants from '
#               'the Geographic Society undertake a journey through the Alps to '
#               'the Sun which finishes under the sea.',
#   'genre': 'Short, Adventure, Fantasy',
#   'imdbID': 499,
#   'imdbRating': 7.7,
#   'imdbVotes': 2022,
#   'language': 'French',
#   'lastupdated': '2015-08-26 00:06:49.650000000',
#   'metacritic': '',
#   'plot': 'Using every known means of transportation, several savants from the '
#           'Geographic Society undertake a journey through the Alps to the Sun '
#           'which finishes under the sea.',
#   'poster': 'http://ia.media-imdb.com/images/M/MV5BMTYxNjExMzk5Nl5BMl5BanBnXkFtZTgwMzE5MjAwMzE@._V1_SX300.jpg',
#   'rating': '',
#   'released': '1904-10-01',
#   'runtime': '24 min',
#   'title': 'The Voyage Across the Impossible',
#   'type': 'movie',
#   'writer': "Georges M�li�s, Jules Verne (play), Adolphe d'Ennery (play)",
#   'year': 1904},
#  {'_id': ObjectId('5a3767934d68d8f31b2caa1c'),
#   'awards': '',
#   'cast': '',
#   'country': 'USA',
#   'director': 'G.W. Bitzer',
#   'fullplot': 'Starting at Union Square, we are taken for an underground '
#               'excursion, following the path of a subway train as it makes its '
#               'way through New York City subway tunnels on its journey to the '
#               'old Grand Central Station.',
#   'genre': 'Short, Documentary',
#   'imdbID': 524,
#   'imdbRating': 5.7,
#   'imdbVotes': 466,
#   'language': '',
#   'lastupdated': '2015-08-29 00:28:39.077000000',
#   'metacritic': '',
#   'plot': 'Starting at Union Square, we are taken for an underground '
#           'excursion, following the path of a subway train as it makes its way '
#           'through New York City subway tunnels on its journey to the old ...',
#   'poster': '',
#   'rating': 'UNRATED',
#   'released': '1905-06-05',
#   'runtime': '6 min',
#   'title': 'New York Subway',
#   'type': 'movie',
#   'writer': '',
#   'year': 1905},
#  {'_id': ObjectId('5a3767934d68d8f31b2caa1d'),
#   'awards': '',
#   'cast': '',
#   'country': 'UK',
#   'director': 'Walter R. Booth',
#   'fullplot': 'A magical glowing white motorcar dismembers policemen, drives '
#               'up buildings, flies through outer space and can transform into '
#               'a horse and carriage. This was a British effort to top Melies '
#               'at his Sci-Fi/fantasy/comedy trick films.',
#   'genre': 'Fantasy, Short, Comedy',
#   'imdbID': 534,
#   'imdbRating': 6.8,
#   'imdbVotes': 467,
#   'language': 'English',
#   'lastupdated': '2015-08-29 00:28:54.797000000',
#   'metacritic': '',
#   'plot': 'A British trick film in which a motorist ends up driving around the '
#           'rings of Saturn.',
#   'poster': '',
#   'rating': '',
#   'released': '1906-10-01',
#   'runtime': '3 min',
#   'title': "The '?' Motorist",
#   'type': 'movie',
#   'writer': '',
#   'year': 1906},
#  {'_id': ObjectId('5a3767934d68d8f31b2caa1e'),
#   'awards': '',
#   'cast': 'Segundo de Chom�n, Julienne Mathieu',
#   'country': 'Spain, France',
#   'director': 'Segundo de Chom�n',
#   'fullplot': 'According to the rapid strides that electricity is making in '
#               'this wonderful age we are not surprised to see in this picture '
#               'an ideal hotel of the future in which everything is done by '
#               'electricity. We see a couple entering the hostelry and, after '
#               'registering, the clerk touches a button and away goes the '
#               'baggage on to the elevator, which stops at the proper floors '
#               'and the grips enter the room without the aid of anyone. Many '
#               'amusing incidents follow. Finally they pay the penalty for all '
#               'the latest improvements, for something goes wrong with the '
#               'electric plant in the cellar and mixes the whole place up. We '
#               'see all the furnishings start to turn in all directions and the '
#               'unfortunate guests find themselves in the midst of the affray. '
#               'They manage to get to the door and are tumbled out and rolled '
#               'across the street till out of the reach of the magnetic force, '
#               'where they pick up their belongings and hurry home, vowing '
#               'never to enter another electric hotel.',
#   'genre': 'Animation, Short',
#   'imdbID': 516,
#   'imdbRating': 6.7,
#   'imdbVotes': 481,
#   'language': '',
#   'lastupdated': '2015-08-29 00:28:28.703000000',
#   'metacritic': '',
#   'plot': 'According to the rapid strides that electricity is making in this '
#           'wonderful age we are not surprised to see in this picture an ideal '
#           'hotel of the future in which everything is done by ...',
#   'poster': '',
#   'rating': '',
#   'released': '1908-12-19',
#   'runtime': '8 min',
#   'title': 'The Electric Hotel',
#   'type': 'movie',
#   'writer': '',
#   'year': 1908},
#  {'_id': ObjectId('5a3767934d68d8f31b2caa1f'),
#   'awards': '',
#   'cast': 'Jack Brawn',
#   'country': 'USA',
#   'director': 'Wallace McCutcheon, Edwin S. Porter',
#   'fullplot': "Adapted from Winsor McCay's films and comics of the period, "
#               'this film follows the established theme: the "Rarebit Fiend" '
#               'gorges himself on rarebit and thus suffers spectacular '
#               'hallucinatory dreams.',
#   'genre': 'Short, Fantasy',
#   'imdbID': 546,
#   'imdbRating': 6.7,
#   'imdbVotes': 1082,
#   'language': 'English',
#   'lastupdated': '2015-08-29 00:29:11.733000000',
#   'metacritic': '',
#   'plot': 'The fiend faces the spectacular mind-bending consequences of his '
#           'free-wheeling rarebit binge.',
#   'poster': '',
#   'rating': '',
#   'released': '1906-02-01',
#   'runtime': '7 min',
#   'title': 'Dream of a Rarebit Fiend',
#   'type': 'movie',
#   'writer': 'Winsor McCay (comic strip)',
#   'year': 1906},
#  {'_id': ObjectId('5a3767934d68d8f31b2caa20'),
#   'awards': '',
#   'cast': 'J. Stuart Blackton',
#   'country': 'USA',
#   'director': 'J. Stuart Blackton',
#   'fullplot': 'Considered the first truly animated movie (or at least the '
#               'first verifiable, surviving animation), this film is based on '
#               'the lightning-sketch, a popular vaudeville act. The artist '
#               '(Blackton) draws a series of faces on a blackboard, which then '
#               'seem to take on a life of their own.',
#   'genre': 'Animation, Short, Comedy',
#   'imdbID': 554,
#   'imdbRating': 6.2,
#   'imdbVotes': 625,
#   'language': '',
#   'lastupdated': '2015-08-29 00:29:22.593000000',
#   'metacritic': '',
#   'plot': 'A cartoonist draws faces and figures on a blackboard - and they '
#           'come to life.',
# ...
#   'language': 'English',
#   'lastupdated': '2015-06-17 18:42:22.767000000',
#   'metacritic': '',
#   'plot': 'The parallel stories of a modern preacher and a medieval monk, '
#           'Gabriel the Ascetic, who is killed by an ignorant mob for making a '
#           'nude statue representing Truth, which is also represented by a '
#           'ghostly naked girl who flits throughout the film.',
#   'poster': 'http://ia.media-imdb.com/images/M/MV5BMjA5NTYzNDQ4NV5BMl5BanBnXkFtZTgwMzA5NzgwMzE@._V1._CR1,92,425,407_SY132_CR24,0,89,132_AL_.jpg_V1_SX300.jpg',
#   'rating': 'PASSED',
#   'released': '1915-01-20',
#   'runtime': '54 min',
#   'title': 'Hypocrites',
#   'type': 'movie',
#   'writer': 'Lois Weber',
#   'year': 1915},
#  {'_id': ObjectId('5a3767934d68d8f31b2caa54'),
#   'awards': '1 win.',
#   'cast': 'Stanley Hunt, Sarah Constance Smith Hunt, Mrs. George Walkus, Paddy '
#           "'Malid",
#   'country': 'USA',
#   'director': 'Edward S. Curtis',
#   'fullplot': '',
#   'genre': 'Drama, History',
#   'imdbID': 4150,
#   'imdbRating': 5.8,
#   'imdbVotes': 223,
#   'language': 'English',
#   'lastupdated': '2015-09-16 12:11:37.770000000',
#   'metacritic': '',
#   'plot': 'Original advertising for the film describes it as a drama of '
#           'primitive life on the shores of the North Pacific...',
#   'poster': 'http://ia.media-imdb.com/images/M/MV5BMjE3ODk0NTAwNF5BMl5BanBnXkFtZTcwNjU2MzYyMQ@@._V1_SX300.jpg',
#   'rating': '',
#   'released': '1914-12-07',
#   'runtime': '65 min',
#   'title': 'In the Land of the Head Hunters',
#   'type': 'movie',
#   'writer': 'Edward S. Curtis (story)',
#   'year': 1914},
#  {'_id': ObjectId('5a3767934d68d8f31b2caa55'),
#   'awards': '',
#   'cast': 'Blanche Sweet, Henry B. Walthall, Mae Marsh, Robert Harron',
#   'country': 'USA',
#   'director': 'D.W. Griffith',
#   'fullplot': 'A fascinating work of high artistry, "Judith of Bethulia" will '
#               'not only rank as an achievement in this country, but will make '
#               'foreign producers sit up and take notice. It has a signal and '
#               'imperative message, and the technique displayed throughout an '
#               'infinity of detail, embracing even the delicate film tinting '
#               'and toning, marks an encouraging step in the development of the '
#               'new art. Ancient in story and settings, it is modern in '
#               'penetrative interpretation - it is a vivid history of one phase '
#               'of the time it concerns, and is redemptive as well as relative, '
#               'a lesson from one of those vital struggles that made and unmade '
#               'nations as well as individuals, yet it is not without that '
#               'inspiring influence that appeals powerfully to human sense of '
#               'justice. The entire vigorous action of the play works up to the '
#               'personal sacrifice of Judith of Bethulia, a perilous chance she '
#               'takes for the sake of the lives and happiness of her people. '
#               'She dares expose herself to overwhelming humiliation and '
#               'dishonor in a challenge of beauty to strength, struggles '
#               'through a conversion of sentiment that makes the high crisis '
#               'more acute, and sets at defiance the '
#               '"better-death-than-dishonor" platitude, escaping both through '
#               'that all-conquering combination in a woman, great physical '
#               'beauty joined to lofty intelligence. She enters upon a relation '
#               'of constant peril - only delicate treatment saves the situation '
#               'at times - abandons her native purity of conduct and dares her '
#               'own undoing, yet the noble end justified the dangerous means, '
#               'and she emerges idealized by her people, an apotheosis of '
#               'splendid womanhood. Bethulia is a fortified town of Judea, '
#               'guarding a hill pass through which an invading Assyrian army '
#               'must march in order to enter Judea. In the town lives Judith, a '
#               'devout young woman of lofty character and remarkable beauty, '
#               'when the place is stormed by Holofernes at the head of a large '
#               'army. The fighting before the gate brings into action an '
#               'enormous number of soldiers on both sides, and those engines of '
#               'war, such as the battering ram and catapult, which were used by '
#               'the fighting male of other days under close condition of '
#               'furious combat. One desperate assault after another is '
#               'repelled, scaling ladders are thrown down, great rocks are '
#               'showered upon the invaders, and the wonder is that they keep at '
#               'it. The reason is that Holofernes has a way of torturing and '
#               'killing unsuccessful captains. As officer had better die in the '
#               'thick of battle than return with a confession of defeat. '
#               'Holofernes is as merciless as nature to all who fail. The great '
#               "leader's brutality of his captains when they do not succeed in "
#               'carrying the fortress by storm indicates what the inhabitants '
#               'of Bethulia may expect in the event of capture and serves to '
#               'intensify the clash of character later on - it adds peril to '
#               'the undertaking of Judith when she resolves to sacrifice '
#               'herself for her people. Holofernes, after making a horrible '
#               'example of defeated captains by frightful torture, resorts to '
#               'strategy. His soldiers have seized the wells from which the '
#               'inhabitants of Bethulia obtained their water supply, and their '
#               'leader adopts waiting tactics, diverting himself with dancing '
#               'girls to break the tedium. Bethulia is on the verge of famine, '
#               'and the besieged are almost ready to surrender the fortress and '
#               'all Judea to the spoilers, when Judith goes forth in her finest '
#               'raiment, accompanied only by her maid, enters the Assryian camp '
#               'and obtains an interview with the merciless Holofernes. Against '
#               'his formidable strength, his brutal ferocity and cunning, his '
#               'absolute power, are matched her fascinating personality '
#               'directed by intelligence and hidden purpose. She is willing to '
#               'carry "her fault on her shoulders like a coronation mantle." '
#               'The dangerous and difficult situation from this point to '
#               "Judith's terrible triumph and the defeat of the invading "
#               'Assyrians is pictured without loss of force or charm by extreme '
#               'delicacy of treatment. Beauty is constantly asserted by almost '
#               'reckless prodigality in the matter of costume, and by the '
#               'appeal of delightful acting. The feminine sweetness and shyness '
#               'of the lovely Judith are intensified by her advances and '
#               'retreats in measuring her sex attractions against his '
#               'formidable power. She is weakened at the critical moment by a '
#               'sudden flame of passion and compassion aroused in her breast, '
#               'but self-control returns at a thought of all that is at stake, '
#               'the safety and happiness of thousands of her people, and she '
#               'dares be all and do all that revolts her finer nature from a '
#               'deep hatred of injustice and wrong meted out to her '
#               'peace-loving kindred and friends, from a noble desire to '
#               'preserve her country and the destinies of her race.',
#   'genre': 'Drama',
#   'imdbID': 4181,
#   'imdbRating': 7.7,
#   'imdbVotes': 897,
#   'language': 'English',
#   'lastupdated': '2015-09-17 04:49:55.737000000',
#   'metacritic': '',
#   'plot': 'A religious woman seeks to save her people from destruction by '
#           'seducing and murdering the enemy leader, but her plans get '
#           'complicated once she falls for him.',
#   'poster': 'http://ia.media-imdb.com/images/M/MV5BMjA3NjgzMjY1N15BMl5BanBnXkFtZTcwNjAzMjM5OA@@._V1._CR221.88333129882812,0.5333404541015625,1055,1410.0999603271484_SY132_CR5,0,89,132_AL_.jpg_V1_SX300.jpg',
#   'rating': '',
#   'released': '1914-03-08',
#   'runtime': '61 min',
#   'title': 'Judith of Bethulia',
#   'type': 'movie',
#   'writer': 'Thomas Bailey Aldrich (poem), D.W. Griffith, Grace Pierce, Frank '
#             'E. Woods',
#   'year': 1914},
#  {'_id': ObjectId('5a3767934d68d8f31b2caa56'),
#   'awards': '',
#   'cast': "Dan Albert, Roscoe 'Fatty' Arbuckle, Charles Avery, Joe Bordeaux",
#   'country': 'USA',
#   'director': 'Mack Sennett',
#   'fullplot': 'A couple of tramps, down on their luck and hungry, decide to '
#               'fake an exhibition boxing match for a promoter. Meanwhile, Pug, '
#               'a good-hearted but boisterous fellow, takes on a gang of '
#               'mashers who make unwanted advances to his girlfriend. Impressed '
#               'by his abilities, the mashers decide to pass Pug off as Cyclone '
#               'Flynn, the champion, and enter him in the boxing match. But the '
#               'real Cyclone shows up, and he and Pug battle it out in the '
#               'ring. Soon the fight progresses to include pistols, rooftop '
#               'chases, and the Keystone Kops in hot pursuit.',
#   'genre': 'Short, Comedy',
#   'imdbID': 4194,
#   'imdbRating': 5.9,
#   'imdbVotes': 720,
#   'language': 'English',
#   'lastupdated': '2015-09-12 00:31:19.700000000',
#   'metacritic': '',
#   'plot': 'To show his girl how brave he is Fatty challenges the champion to a '
#           'fight. Charlie referees, trying to avoid contact with the two '
#           'monsters.',
#   'poster': '',
#   'rating': 'TV-G',
#   'released': '1914-06-11',
#   'runtime': '27 min',
#   'title': 'The Knockout',
#   'type': 'movie',
#   'writer': '',
#   'year': 1914},
#  {'_id': ObjectId('5a3767934d68d8f31b2caa57'),
#   'awards': '',
#   'cast': 'Charles Chaplin, Fritz Schade, Alice Howell, Slim Summerville',
#   'country': 'USA',
#   'director': 'Charles Chaplin',
#   'fullplot': 'Charlie pretends to be a dentist though he is only his '
#               "assistant. When a patient can't stop laughing from the "
#               'anesthesia Charlie knocks him out with a club. He is sent to '
#               'the drug store, gets in a fight with a man who (after a brick '
#               'in the face) becomes another patient, and pulls the skirt off '
#               "the dentist's wife (who is out walking). At one point Charlie "
#               'pulls a tooth (the wrong one) using enormous pliers.',
#   'genre': 'Short, Comedy',
#   'imdbID': 4210,
#   'imdbRating': 5.7,
#   'imdbVotes': 739,
#   'language': 'English',
#   'lastupdated': '2015-07-18 00:56:55.850000000',
#   'metacritic': '',
#   'plot': 'Charlie pretends to be a dentist though he is only his assistant. '
#           "When a patient can't stop laughing from the anesthesia Charlie "
#           'knocks him out with a club. He is sent to the drug store, ...',
#   'poster': 'http://ia.media-imdb.com/images/M/MV5BMTk1MjMyNzMxMF5BMl5BanBnXkFtZTYwMTQ3ODc5._V1_SX300.jpg',
#   'rating': '',
#   'released': '1914-07-09',
#   'runtime': '16 min',
#   'title': 'Laughing Gas',
#   'type': 'movie',
#   'writer': '',
#   'year': 1914},
#  {'_id': ObjectId('5a3767934d68d8f31b2caa58'),
#   'awards': '',
#   'cast': 'Charles Chaplin, Mabel Normand, Mack Swain, Eva Nelson',
#   'country': 'USA',
#   'director': 'Mack Sennett',
#   'fullplot': 'Mabel goes home after being humiliated by a masher whom her '
#               "wimpy husband won't fight. The husband goes off to a bar and "
#               'gets drunk. She buys a boxing dummy hoping it will inspire her '
#               'husband, but when he returns he gets in a fight with it, taking '
#               'it to be the ladykiller.',
#   'genre': 'Short, Comedy',
#   'imdbID': 4282,
#   'imdbRating': 5.8,
#   'imdbVotes': 665,
#   'language': 'English',
#   'lastupdated': '2015-04-25 00:32:22.557000000',
#   'metacritic': '',
#   'plot': 'Accosted by a masher in the park and unable to motivate husband '
#           'Charlie into taking action, Mabel gets him a boxing mannequin to '
#           'sharpen his fighting skills.',
#   'poster': '',
#   'rating': '',
#   'released': '1914-06-20',
#   'runtime': '17 min',
#   'title': "Mabel's Married Life",
#   'type': 'movie',
#   'writer': 'Charles Chaplin, Mabel Normand',
#   'year': 1914},
#  {'_id': ObjectId('5a3767934d68d8f31b2caa59'),
#   'awards': '',
#   'cast': 'Charles Chaplin, Mabel Normand, Harry McCoy, Chester Conklin',
#   'country': 'USA',
#   'director': 'Mabel Normand, Mack Sennett',
#   'fullplot': "Charlie, competing with his rival's race car, offers Mabel a "
#               'ride on his motorcycle but drops her in a puddle. He next joins '
#               'some dubious characters in abduction of his rival just before '
#               'the race for the Vanderbilt Cup. With her boyfriend locked up '
#               'in a shed, Mabel takes his place. Charlie does what he can to '
#               "sabotage the race, even causing Mabel's car to overturn.",
#   'genre': 'Short, Comedy',
#   'imdbID': 4277,
#   'imdbRating': 5.7,
#   'imdbVotes': 433,
#   'language': 'English',
#   'lastupdated': '2015-08-14 01:11:13.613000000',
#   'metacritic': '',
#   'plot': "Charlie, competing with his rival's race car, offers Mabel a ride "
#           'on his motorcycle but drops her in a puddle. He next joins some '
#           'dubious characters in abduction of his rival just before ...',
#   'poster': '',
#   'rating': '',
#   'released': '1914-04-18',
#   'runtime': '18 min',
#   'title': 'Mabel at the Wheel',
#   'type': 'movie',
#   'writer': '',
#   'year': 1914},
#  {'_id': ObjectId('5a3767934d68d8f31b2caa5a'),
#   'awards': '',
#   'cast': 'Charles Chaplin',
#   'country': 'USA',
#   'director': 'Henry Lehrman',
#   'fullplot': 'An out-of-work swindler takes a job as a reporter. After '
#               "witnessing a car go over cliff, he grabs a rival reporter's "
#               'camera and races to the newspaper office to enter the photo as '
#               "his own. His rival is delayed when he gets caught in a woman's "
#               'bedroom by her jealous husband. The swindler follows the '
#               "distribution of the paper containing his 'scoop' around town "
#               'where he is once again chased by the rival reporter. Both end '
#               'up on the cow-catcher of a streetcar.',
#   'genre': 'Short, Comedy',
#   'imdbID': 4288,
#   'imdbRating': 5.5,
#   'imdbVotes': 1115,
#   'language': 'English',
#   'lastupdated': '2015-09-16 12:00:47.040000000',
#   'metacritic': '',
#   'plot': 'An out-of-work swindler takes a job as a reporter. After witnessing '
#           "a car go over cliff, he grabs a rival reporter's camera and races "
#           'to the newspaper office to enter the photo as his own. ...',
#   'poster': 'http://ia.media-imdb.com/images/M/MV5BMjI0Nzg5MjYxMF5BMl5BanBnXkFtZTcwMzgxODQ4Mg@@._V1._CR102,78,253,333_SY132_CR5,0,89,132_AL_.jpg_V1_SX300.jpg',
#   'rating': 'TV-G',
#   'released': '1914-02-02',
#   'runtime': '13 min',
#   'title': 'Making a Living',
#   'type': 'movie',
#   'writer': '',
#   'year': 1914},
#  {'_id': ObjectId('5a3767934d68d8f31b2caa5b'),
#   'awards': '',
#   'cast': 'Carlyle Blackwell, Doris Kenyon, Edgar Norton, Fraunie Fraunholz',
#   'country': 'USA',
#   'director': 'Alice Guy',
#   'fullplot': 'An abused woman finds love in the arms of a famous novelist.',
#   'genre': 'Short, Comedy, Drama',
#   'imdbID': 4413,
#   'imdbRating': 6.9,
#   'imdbVotes': 66,
#   'language': 'English',
#   'lastupdated': '2015-04-25 00:35:56.167000000',
#   'metacritic': '',
#   'plot': 'An abused woman finds love in the arms of a famous novelist.',
#   'poster': 'http://ia.media-imdb.com/images/M/MV5BMjI3Mjc1OTc3OV5BMl5BanBnXkFtZTgwOTQ2Njk1MDE@._V1_SX300.jpg',
#   'rating': 'UNRATED',
#   'released': '1916-11-02',
#   'runtime': '40 min',
#   'title': 'The Ocean Waif',
#   'type': 'movie',
#   'writer': '',
#   'year': 1916}]
