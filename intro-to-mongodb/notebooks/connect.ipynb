# %%
from pymongo import MongoClient

client = MongoClient("mongodb://analytics:analytics-password@mflix-shard-00-00-uxwrx.mongodb.net:27017,mflix-shard-00-01-uxwrx.mongodb.net:27017,mflix-shard-00-02-uxwrx.mongodb.net:27017/test?ssl=true&replicaSet=mflix-shard-0&authSource=admin")

print(client.mflix)
# Out:
# Database(MongoClient(host=['mflix-shard-00-00-uxwrx.mongodb.net:27017', 'mflix-shard-00-01-uxwrx.mongodb.net:27017', 'mflix-shard-00-02-uxwrx.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, ssl=True, replicaset='mflix-shard-0', authsource='admin'), 'mflix')
